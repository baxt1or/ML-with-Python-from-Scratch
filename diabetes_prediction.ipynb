# %%
import numpy as np
import pandas as pd
from sklearn import svm
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("./db/diabetes.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.corr()

# %%
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
df.hist(bins=10,figsize=(10,10))
plt.show()

# %%
X = df.drop(columns="Outcome", axis=1)
y = df["Outcome"]

# %%
scaler = StandardScaler()
scaler.fit(X)
df = scaler.transform(X)

# %%
X = df

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25,stratify=y, random_state=2)

# %%
classifier = svm.SVC(kernel="linear")

# %%
classifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
predictions = classifier.predict(X_train)

# %%
accuracy = accuracy_score(predictions, y_train)
accuracy
# Out:
# 0.7881944444444444

# %%
test_prediction = classifier.predict(X_test)
accuracy = accuracy_score(test_prediction, y_test)
accuracy
# Out:
# 0.765625

# %%
# input_data = (0, 137, 40, 35, 168, 43.1, 2.288, 33)    
input_data = (3,113,44,13,0,22.4,0.14,22)
input_np_data = np.asarray(input_data).reshape(1, -1)
values = scaler.transform(input_np_data)
# Out:
# C:\Users\baxti\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
y_pred = classifier.predict(values)

if y_pred[0] == 0:
    print("Yes, You have a diabetes")
else:
    print("You are lucky one, you dont have a diabetes")
# Out:
# Yes, You have a diabetes

# %%
from sklearn.neighbors import KNeighborsClassifier

knn =KNeighborsClassifier()

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
predictions = knn.predict(X_train)
accuracy = accuracy_score(predictions, y_train)
print(accuracy)
# Out:
# 0.8229166666666666

# %%
predictions = knn.predict(X_test)
accuracy = accuracy_score(predictions, y_test)
print(accuracy)
# Out:
# 0.7395833333333334

# %%
input_data = (3,113,44,13,0,22.4,0.14,22)
input_np_data = np.asarray(input_data).reshape(1, -1)
values = scaler.transform(input_np_data)
# Out:
# C:\Users\baxti\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
y_pred = knn.predict(values)

if y_pred[0] == 0:
    print("Yes, You have a diabetes")
else:
    print("You are lucky one, you dont have a diabetes")
# Out:
# Yes, You have a diabetes
